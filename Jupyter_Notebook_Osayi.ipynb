# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Osayi Omorodion**
#
# Planning Manager

# %% [markdown]
# *I am interested in data science because it is a field that is transforming business decision making and problem solving. I also enjoy analysing data to uncover hidden patterns.*

# %% [markdown]
# ### The code below is to display how I am feeling today (hint: happy)

# %%
x = "I feel happy"
print(x)
# Out:
# I feel happy

# %% [markdown]
# | Fruits | Drinks |
# |----------|----------|
# | Citrus | Water |
# | Apple | Milk |
# | Banana | Soda |
#
# ~~Circus~~ Citrus Examples:
# * Oranges
# * Lemon
# * Lime
# * ~~Watermelon~~
